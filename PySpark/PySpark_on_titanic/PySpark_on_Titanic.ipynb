# %% [markdown]
# ### What is Spark?
# Spark is a platform for cluster computing. Spark lets us spread data and computations over clusters with multiple nodes (think of each node as a separate computer). Splitting up data makes it easier to work with very large datasets because each node only works with a small amount of data.
# As each node works on its own subset of the total data, it also carries out a part of the total calculations required, so that both data processing and computation are performed in parallel over the nodes in the cluster. It is a fact that parallel computation can make certain types of programming tasks much faster.
#
# Deciding whether or not Spark is the best solution for your problem takes some experience, but you can consider questions like:
# * Is my data too big to work with on a single machine?
# * Can my calculations be easily parallelized?

# %%
## Create a Spark Session
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("tutorial").getOrCreate()

# %%
df_train = spark.read.csv('/content/train-2.csv',header = True, inferSchema=True)
df_test = spark.read.csv('/content/test-2.csv',header = True, inferSchema=True)

# %%
df_train.show()
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25| NULL|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925| NULL|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|35.0|    0|    0|          373450|   8.05| NULL|       S|
# |          6|       0|     3|    Moran, Mr. James|  male|NULL|    0|    0|          330877| 8.4583| NULL|       Q|
# |          7|       0|     1|McCarthy, Mr. Tim...|  male|54.0|    0|    0|           17463|51.8625|  E46|       S|
# |          8|       0|     3|Palsson, Master. ...|  male| 2.0|    3|    1|          349909| 21.075| NULL|       S|
# |          9|       1|     3|Johnson, Mrs. Osc...|female|27.0|    0|    2|          347742|11.1333| NULL|       S|
# |         10|       1|     2|Nasser, Mrs. Nich...|female|14.0|    1|    0|          237736|30.0708| NULL|       C|
# |         11|       1|     3|Sandstrom, Miss. ...|female| 4.0|    1|    1|         PP 9549|   16.7|   G6|       S|
# |         12|       1|     1|Bonnell, Miss. El...|female|58.0|    0|    0|          113783|  26.55| C103|       S|
# |         13|       0|     3|Saundercock, Mr. ...|  male|20.0|    0|    0|       A/5. 2151|   8.05| NULL|       S|
# |         14|       0|     3|Andersson, Mr. An...|  male|39.0|    1|    5|          347082| 31.275| NULL|       S|
# |         15|       0|     3|Vestrom, Miss. Hu...|female|14.0|    0|    0|          350406| 7.8542| NULL|       S|
# |         16|       1|     2|Hewlett, Mrs. (Ma...|female|55.0|    0|    0|          248706|   16.0| NULL|       S|
# |         17|       0|     3|Rice, Master. Eugene|  male| 2.0|    4|    1|          382652| 29.125| NULL|       Q|
# |         18|       1|     2|Williams, Mr. Cha...|  male|NULL|    0|    0|          244373|   13.0| NULL|       S|
# |         19|       0|     3|Vander Planke, Mr...|female|31.0|    1|    0|          345763|   18.0| NULL|       S|
# |         20|       1|     3|Masselmani, Mrs. ...|female|NULL|    0|    0|            2649|  7.225| NULL|       C|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# only showing top 20 rows

# %%
df_train.toPandas()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888       "Johnston, Miss. Catherine Helen ""Carrie"""  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %%
df_train.describe().toPandas()
# Out:
#   summary        PassengerId             Survived              Pclass  \
# 0   count                891                  891                 891
# 1    mean              446.0   0.3838383838383838   2.308641975308642
# 2  stddev  257.3538420152301  0.48659245426485753  0.8360712409770491
# 3     min                  1                    0                   1
# 4     max                891                    1                   3
#
#                                                Name     Sex  \
# 0                                               891     891
# 1                                              None    None
# 2                                              None    None
# 3  "Andersson, Mr. August Edvard (""Wennerstrom"")"  female
# 4                       van Melkebeke, Mr. Philemon    male
#
#                   Age               SibSp                Parch  \
# 0                 714                 891                  891
# 1   29.69911764705882  0.5230078563411896  0.38159371492704824
# 2  14.526497332334035  1.1027434322934315   0.8060572211299488
# 3                0.42                   0                    0
# 4                80.0                   8                    6
#
#                Ticket               Fare Cabin Embarked
# 0                 891                891   204      889
# 1  260318.54916792738   32.2042079685746  None     None
# 2  471609.26868834975  49.69342859718089  None     None
# 3              110152                0.0   A10        C
# 4           WE/P 5735           512.3292     T        S

# %%
df_train.count()
# Out:
# 891

# %%
df_train.printSchema()
# Out:
# root
#  |-- PassengerId: integer (nullable = true)
#  |-- Survived: integer (nullable = true)
#  |-- Pclass: integer (nullable = true)
#  |-- Name: string (nullable = true)
#  |-- Sex: string (nullable = true)
#  |-- Age: double (nullable = true)
#  |-- SibSp: integer (nullable = true)
#  |-- Parch: integer (nullable = true)
#  |-- Ticket: string (nullable = true)
#  |-- Fare: double (nullable = true)
#  |-- Cabin: string (nullable = true)
#  |-- Embarked: string (nullable = true)

# %%
df_train.dtypes
# Out:
# [('PassengerId', 'int'),
#  ('Survived', 'int'),
#  ('Pclass', 'int'),
#  ('Name', 'string'),
#  ('Sex', 'string'),
#  ('Age', 'double'),
#  ('SibSp', 'int'),
#  ('Parch', 'int'),
#  ('Ticket', 'string'),
#  ('Fare', 'double'),
#  ('Cabin', 'string'),
#  ('Embarked', 'string')]

# %% [markdown]
# ### Registering a Temporary SQL views

# %%
df_train.createOrReplaceTempView('myTable');
result = spark.sql("SELECT * FROM myTable ORDER BY Fare DESC LIMIT 10")
result.toPandas()
# Out:
#    PassengerId  Survived  Pclass                                       Name  \
# 0          680         1       1         Cardeza, Mr. Thomas Drake Martinez
# 1          259         1       1                           Ward, Miss. Anna
# 2          738         1       1                     Lesurer, Mr. Gustave J
# 3           89         1       1                 Fortune, Miss. Mabel Helen
# 4           28         0       1             Fortune, Mr. Charles Alexander
# 5          342         1       1             Fortune, Miss. Alice Elizabeth
# 6          439         0       1                          Fortune, Mr. Mark
# 7          312         1       1                 Ryerson, Miss. Emily Borie
# 8          743         1       1  "Ryerson, Miss. Susan Parker ""Suzette"""
# 9          119         0       1                   Baxter, Mr. Quigg Edmond
#
#       Sex   Age  SibSp  Parch    Ticket      Fare            Cabin Embarked
# 0    male  36.0      0      1  PC 17755  512.3292      B51 B53 B55        C
# 1  female  35.0      0      0  PC 17755  512.3292             None        C
# 2    male  35.0      0      0  PC 17755  512.3292             B101        C
# 3  female  23.0      3      2     19950  263.0000      C23 C25 C27        S
# 4    male  19.0      3      2     19950  263.0000      C23 C25 C27        S
# 5  female  24.0      3      2     19950  263.0000      C23 C25 C27        S
# 6    male  64.0      1      4     19950  263.0000      C23 C25 C27        S
# 7  female  18.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 8  female  21.0      2      2  PC 17608  262.3750  B57 B59 B63 B66        C
# 9    male  24.0      0      1  PC 17558  247.5208          B58 B60        C

# %%
df_test.createOrReplaceTempView("df_test")

# %%
spark.catalog.listTables()
# Out:
# [Table(name='df_test', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True),
#  Table(name='mytable', catalog=None, namespace=[], description=None, tableType='TEMPORARY', isTemporary=True)]

# %%
spark.sql("SHOW views").show()
# Out:
# +---------+--------+-----------+
# |namespace|viewName|isTemporary|
# +---------+--------+-----------+
# |         | df_test|       true|
# |         | mytable|       true|
# +---------+--------+-----------+

# %%
temp_table = spark.table("df_test")
print(type(temp_table))
# Out:
# <class 'pyspark.sql.classic.dataframe.DataFrame'>

# %%
temp_table.show(5)
# Out:
# +-----------+------+--------------------+------+----+-----+-----+-------+-------+-----+--------+
# |PassengerId|Pclass|                Name|   Sex| Age|SibSp|Parch| Ticket|   Fare|Cabin|Embarked|
# +-----------+------+--------------------+------+----+-----+-----+-------+-------+-----+--------+
# |        892|     3|    Kelly, Mr. James|  male|34.5|    0|    0| 330911| 7.8292| NULL|       Q|
# |        893|     3|Wilkes, Mrs. Jame...|female|47.0|    1|    0| 363272|    7.0| NULL|       S|
# |        894|     2|Myles, Mr. Thomas...|  male|62.0|    0|    0| 240276| 9.6875| NULL|       Q|
# |        895|     3|    Wirz, Mr. Albert|  male|27.0|    0|    0| 315154| 8.6625| NULL|       S|
# |        896|     3|Hirvonen, Mrs. Al...|female|22.0|    1|    1|3101298|12.2875| NULL|       S|
# +-----------+------+--------------------+------+----+-----+-----+-------+-------+-----+--------+
# only showing top 5 rows

# %%
df_train.columns
# Out:
# ['PassengerId',
#  'Survived',
#  'Pclass',
#  'Name',
#  'Sex',
#  'Age',
#  'SibSp',
#  'Parch',
#  'Ticket',
#  'Fare',
#  'Cabin',
#  'Embarked']

# %%
df_train['Survived']
# Out:
# Column<'Survived'>

# %%
df_train.Age
# Out:
# Column<'Age'>

# %%
type(df_train['Survived'])
# Out:
# pyspark.sql.classic.column.Column

# %%
df_train.select('Survived')
# Out:
# DataFrame[Survived: int]

# %%
df_train.toPandas()
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888       "Johnston, Miss. Catherine Helen ""Carrie"""  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %%
row = df_train.head(5)[0]
row
# Out:
# Row(PassengerId=1, Survived=0, Pclass=3, Name='Braund, Mr. Owen Harris', Sex='male', Age=22.0, SibSp=1, Parch=0, Ticket='A/5 21171', Fare=7.25, Cabin=None, Embarked='S')

# %%
type(row)
# Out:
# pyspark.sql.types.Row

# %%
row.asDict()
# Out:
# {'PassengerId': 1,
#  'Survived': 0,
#  'Pclass': 3,
#  'Name': 'Braund, Mr. Owen Harris',
#  'Sex': 'male',
#  'Age': 22.0,
#  'SibSp': 1,
#  'Parch': 0,
#  'Ticket': 'A/5 21171',
#  'Fare': 7.25,
#  'Cabin': None,
#  'Embarked': 'S'}

# %%
row.asDict()['Ticket']
# Out:
# 'A/5 21171'

# %%
row.asDict()['Name']
# Out:
# 'Braund, Mr. Owen Harris'

# %%
df_renamed = df_train.withColumnRenamed('Pclass','Passesnger_Class')
df_renamed.toPandas()
# Out:
#      PassengerId  Survived  Passesnger_Class  \
# 0              1         0                 3
# 1              2         1                 1
# 2              3         1                 3
# 3              4         1                 1
# 4              5         0                 3
# ..           ...       ...               ...
# 886          887         0                 2
# 887          888         1                 1
# 888          889         0                 3
# 889          890         1                 1
# 890          891         0                 3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888       "Johnston, Miss. Catherine Helen ""Carrie"""  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500  None        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250  None        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500  None        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000  None        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500  None        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500  None        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# SQL functions

# %%
from pyspark.sql.functions import mean
fare_mean = df_train.select(mean('Fare')).collect()
fare_mean[0][0]
# Out:
# 32.2042079685746

# %%
df_train.filter('Fare > 40.20').limit(3).show()
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+--------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|  Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+--------+-------+-----+--------+
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|PC 17599|71.2833|  C85|       C|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|  113803|   53.1| C123|       S|
# |          7|       0|     1|McCarthy, Mr. Tim...|  male|54.0|    0|    0|   17463|51.8625|  E46|       S|
# +-----------+--------+------+--------------------+------+----+-----+-----+--------+-------+-----+--------+

# %%
df_train.select("PassengerId", "Fare").filter(df_train.Fare.between(10,40)).show()
# Out:
# +-----------+-------+
# |PassengerId|   Fare|
# +-----------+-------+
# |          8| 21.075|
# |          9|11.1333|
# |         10|30.0708|
# |         11|   16.7|
# |         12|  26.55|
# |         14| 31.275|
# |         16|   16.0|
# |         17| 29.125|
# |         18|   13.0|
# |         19|   18.0|
# |         21|   26.0|
# |         22|   13.0|
# |         24|   35.5|
# |         25| 21.075|
# |         26|31.3875|
# |         31|27.7208|
# |         34|   10.5|
# |         39|   18.0|
# |         40|11.2417|
# |         42|   21.0|
# +-----------+-------+
# only showing top 20 rows

# %%
df_train.select("PassengerId", "Name").filter(df_train.Name.contains("Mrs")).show()
# Out:
# +-----------+--------------------+
# |PassengerId|                Name|
# +-----------+--------------------+
# |          2|Cumings, Mrs. Joh...|
# |          4|Futrelle, Mrs. Ja...|
# |          9|Johnson, Mrs. Osc...|
# |         10|Nasser, Mrs. Nich...|
# |         16|Hewlett, Mrs. (Ma...|
# |         19|Vander Planke, Mr...|
# |         20|Masselmani, Mrs. ...|
# |         26|Asplund, Mrs. Car...|
# |         32|Spencer, Mrs. Wil...|
# |         41|Ahlin, Mrs. Johan...|
# |         42|Turpin, Mrs. Will...|
# |         50|Arnold-Franchi, M...|
# |         53|Harper, Mrs. Henr...|
# |         54|Faunthorpe, Mrs. ...|
# |         67|Nye, Mrs. (Elizab...|
# |         86|Backstrom, Mrs. K...|
# |         99|Doling, Mrs. John...|
# |        133|Robins, Mrs. Alex...|
# |        134|Weisz, Mrs. Leopo...|
# |        141|Boulos, Mrs. Jose...|
# +-----------+--------------------+
# only showing top 20 rows

# %%
df_train.select("PassengerId", "Sex").filter(df_train.Sex.startswith("fe")).show()
# Out:
# +-----------+------+
# |PassengerId|   Sex|
# +-----------+------+
# |          2|female|
# |          3|female|
# |          4|female|
# |          9|female|
# |         10|female|
# |         11|female|
# |         12|female|
# |         15|female|
# |         16|female|
# |         19|female|
# |         20|female|
# |         23|female|
# |         25|female|
# |         26|female|
# |         29|female|
# |         32|female|
# |         33|female|
# |         39|female|
# |         40|female|
# |         41|female|
# +-----------+------+
# only showing top 20 rows

# %%
df_train.select("PassengerId", "Ticket").filter(df_train.Ticket.endswith("50")).show()
# Out:
# +-----------+----------+
# |PassengerId|    Ticket|
# +-----------+----------+
# |          5|    373450|
# |         28|     19950|
# |         89|     19950|
# |        256|      2650|
# |        342|     19950|
# |        439|     19950|
# |        537|    113050|
# |        641|    350050|
# |        671|     29750|
# |        672|F.C. 12750|
# |        685|     29750|
# |        768|    364850|
# |        807|    112050|
# +-----------+----------+

# %%
df_train[df_train.PassengerId.isin([1,2,3,4])].show()
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25| NULL|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925| NULL|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+

# %%
df_train.select(df_train.Name.substr(1,5)).show()
# Out:
# +------------------+
# |substr(Name, 1, 5)|
# +------------------+
# |             Braun|
# |             Cumin|
# |             Heikk|
# |             Futre|
# |             Allen|
# |             Moran|
# |             McCar|
# |             Palss|
# |             Johns|
# |             Nasse|
# |             Sands|
# |             Bonne|
# |             Saund|
# |             Ander|
# |             Vestr|
# |             Hewle|
# |             Rice,|
# |             Willi|
# |             Vande|
# |             Masse|
# +------------------+
# only showing top 20 rows

# %%
df_train.groupBy("Pclass").mean().toPandas()
# Out:
#    Pclass  avg(PassengerId)  avg(Survived)  avg(Pclass)   avg(Age)  \
# 0       1        461.597222       0.629630          1.0  38.233441
# 1       3        439.154786       0.242363          3.0  25.140620
# 2       2        445.956522       0.472826          2.0  29.877630
#
#    avg(SibSp)  avg(Parch)  avg(Fare)
# 0    0.416667    0.356481  84.154687
# 1    0.615071    0.393075  13.675550
# 2    0.402174    0.380435  20.662183

# %%
df_train.agg({'Fare':'mean'}).show()
# Out:
# +----------------+
# |       avg(Fare)|
# +----------------+
# |32.2042079685746|
# +----------------+

# %%
from pyspark.sql.functions import format_number
temp = df_train.groupBy("Pclass")
temp = temp.agg({'Fare':'mean'})
temp.select('Pclass', format_number("avg(Fare)", 2).alias("Average Fare")).show()
# Out:
# +------+------------+
# |Pclass|Average Fare|
# +------+------------+
# |     1|       84.15|
# |     3|       13.68|
# |     2|       20.66|
# +------+------------+

# %%
df_train.orderBy("Fare").toPandas()
# Out:
#      PassengerId  Survived  Pclass                                Name  \
# 0            180         0       3                 Leonard, Mr. Lionel
# 1            264         0       1               Harrison, Mr. William
# 2            272         1       3        Tornquist, Mr. William Henry
# 3            278         0       2     "Parkes, Mr. Francis ""Frank"""
# 4            303         0       3     Johnson, Mr. William Cahoone Jr
# ..           ...       ...     ...                                 ...
# 886          342         1       1      Fortune, Miss. Alice Elizabeth
# 887          439         0       1                   Fortune, Mr. Mark
# 888          259         1       1                    Ward, Miss. Anna
# 889          680         1       1  Cardeza, Mr. Thomas Drake Martinez
# 890          738         1       1              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 0      male  36.0      0      0      LINE    0.0000         None        S
# 1      male  40.0      0      0    112059    0.0000          B94        S
# 2      male  25.0      0      0      LINE    0.0000         None        S
# 3      male   NaN      0      0    239853    0.0000         None        S
# 4      male  19.0      0      0      LINE    0.0000         None        S
# ..      ...   ...    ...    ...       ...       ...          ...      ...
# 886  female  24.0      3      2     19950  263.0000  C23 C25 C27        S
# 887    male  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 888  female  35.0      0      0  PC 17755  512.3292         None        C
# 889    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 890    male  35.0      0      0  PC 17755  512.3292         B101        C
#
# [891 rows x 12 columns]

# %%
df_train.filter(df_train.Embarked.isNull()).count()
# Out:
# 2

# %%
df_train.select("PassengerId","Embarked").orderBy(df_train.Embarked.asc_nulls_first()).show()
# Out:
# +-----------+--------+
# |PassengerId|Embarked|
# +-----------+--------+
# |         62|    NULL|
# |        830|    NULL|
# |        204|       C|
# |         74|       C|
# |         66|       C|
# |         97|       C|
# |         65|       C|
# |         98|       C|
# |         31|       C|
# |        112|       C|
# |         35|       C|
# |        115|       C|
# |         40|       C|
# |        119|       C|
# |         44|       C|
# |        123|       C|
# |         53|       C|
# |        126|       C|
# |         58|       C|
# |         10|       C|
# +-----------+--------+
# only showing top 20 rows

# %%
df_train.filter(df_train.Cabin.isNull()).count()
# Out:
# 687

# %%
df_train = df_train.na.fill("N", subset=['Cabin'])

# %%
df_train.show()
# Out:
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |PassengerId|Survived|Pclass|                Name|   Sex| Age|SibSp|Parch|          Ticket|   Fare|Cabin|Embarked|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# |          1|       0|     3|Braund, Mr. Owen ...|  male|22.0|    1|    0|       A/5 21171|   7.25|    N|       S|
# |          2|       1|     1|Cumings, Mrs. Joh...|female|38.0|    1|    0|        PC 17599|71.2833|  C85|       C|
# |          3|       1|     3|Heikkinen, Miss. ...|female|26.0|    0|    0|STON/O2. 3101282|  7.925|    N|       S|
# |          4|       1|     1|Futrelle, Mrs. Ja...|female|35.0|    1|    0|          113803|   53.1| C123|       S|
# |          5|       0|     3|Allen, Mr. Willia...|  male|35.0|    0|    0|          373450|   8.05|    N|       S|
# |          6|       0|     3|    Moran, Mr. James|  male|NULL|    0|    0|          330877| 8.4583|    N|       Q|
# |          7|       0|     1|McCarthy, Mr. Tim...|  male|54.0|    0|    0|           17463|51.8625|  E46|       S|
# |          8|       0|     3|Palsson, Master. ...|  male| 2.0|    3|    1|          349909| 21.075|    N|       S|
# |          9|       1|     3|Johnson, Mrs. Osc...|female|27.0|    0|    2|          347742|11.1333|    N|       S|
# |         10|       1|     2|Nasser, Mrs. Nich...|female|14.0|    1|    0|          237736|30.0708|    N|       C|
# |         11|       1|     3|Sandstrom, Miss. ...|female| 4.0|    1|    1|         PP 9549|   16.7|   G6|       S|
# |         12|       1|     1|Bonnell, Miss. El...|female|58.0|    0|    0|          113783|  26.55| C103|       S|
# |         13|       0|     3|Saundercock, Mr. ...|  male|20.0|    0|    0|       A/5. 2151|   8.05|    N|       S|
# |         14|       0|     3|Andersson, Mr. An...|  male|39.0|    1|    5|          347082| 31.275|    N|       S|
# |         15|       0|     3|Vestrom, Miss. Hu...|female|14.0|    0|    0|          350406| 7.8542|    N|       S|
# |         16|       1|     2|Hewlett, Mrs. (Ma...|female|55.0|    0|    0|          248706|   16.0|    N|       S|
# |         17|       0|     3|Rice, Master. Eugene|  male| 2.0|    4|    1|          382652| 29.125|    N|       Q|
# |         18|       1|     2|Williams, Mr. Cha...|  male|NULL|    0|    0|          244373|   13.0|    N|       S|
# |         19|       0|     3|Vander Planke, Mr...|female|31.0|    1|    0|          345763|   18.0|    N|       S|
# |         20|       1|     3|Masselmani, Mrs. ...|female|NULL|    0|    0|            2649|  7.225|    N|       C|
# +-----------+--------+------+--------------------+------+----+-----+-----+----------------+-------+-----+--------+
# only showing top 20 rows

# %%
df_test.where(df_test['Fare'].isNull()).show()
# Out:
# +-----------+------+------------------+----+----+-----+-----+------+----+-----+--------+
# |PassengerId|Pclass|              Name| Sex| Age|SibSp|Parch|Ticket|Fare|Cabin|Embarked|
# +-----------+------+------------------+----+----+-----+-----+------+----+-----+--------+
# |       1044|     3|Storey, Mr. Thomas|male|60.5|    0|    0|  3701|NULL| NULL|       S|
# +-----------+------+------------------+----+----+-----+-----+------+----+-----+--------+

# %%
missing_value = df_test.filter(
    (df_test['Pclass'] == 3) &
    (df_test.Sex == "male") &
    (df_test.Embarked == "S")
)

df_test = df_test.na.fill(
    missing_value.select(mean('Fare')).collect()[0][0],
    subset=['Fare']
)

# %%
df_test.where(df_test['Fare'].isNull()).show()
# Out:
# +-----------+------+----+---+---+-----+-----+------+----+-----+--------+
# |PassengerId|Pclass|Name|Sex|Age|SibSp|Parch|Ticket|Fare|Cabin|Embarked|
# +-----------+------+----+---+---+-----+-----+------+----+-----+--------+
# +-----------+------+----+---+---+-----+-----+------+----+-----+--------+

# %%
df_test.select("PassengerId","Name", "Fare","Cabin").filter(df_test.Name.startswith("Sto")).show()
# Out:
# +-----------+--------------------+---------+-----+
# |PassengerId|                Name|     Fare|Cabin|
# +-----------+--------------------+---------+-----+
# |       1044|  Storey, Mr. Thomas|12.718872| NULL|
# |       1243|Stokes, Mr. Phili...|     10.5| NULL|
# +-----------+--------------------+---------+-----+
